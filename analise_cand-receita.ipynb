# %% [markdown]
# # Análise - Receita dos candidatos a deputado federal em 2018 e 2022
#
# Análise exploratória dos bancos dos candidatos e suas receitas, de 2018 e 2022. Fonte: Dados Abertos do TSE
#
# Trabalho desenvolvido para a disciplina Mineiração de Dados Não Estruturados, do curso de Pós-graduação em Jornalismo de Dados, Automação e Data Storytelling
#
# **Grupo**: Ananda Ridart, Gabriel Ronan, Géssica Brandino e Vitor Arthur

# %% [markdown]
# # Etapa 1: Primeiros Passos
# Importando bibliotecas e fazendo leitura dos bancos de dados

# %%
# instalando bibliotecas
! pip install altair

# %%
# importando bibliotecas
import os
import pandas as pd
import altair as alt

# %%
# recebendo conjunto de dados de despesas dos candidatos em 2022
despesas_cand2022 = pd.read_csv(r'C:\Users\Vitor\Creative Cloud Files\Insper\2º Trimestre\Análise Exploratória de Dados II\Projeto Final\2022\receitas_candidatos_2022_BRASIL.csv',
                          sep = ';',
                          encoding = 'latin1',
                          decimal = ',',
                          low_memory = False)

# %%
# recebendo conjunto de dados dos candidatos em 2022
cand2022 = pd.read_csv(r'C:\Users\Vitor\Creative Cloud Files\Insper\2º Trimestre\Análise Exploratória de Dados II\Projeto Final\2022\consulta_cand_2022_BRASIL.csv',
                          sep = ';',
                          encoding = 'latin1',
                          decimal = ',',
                          low_memory = False)

# %%
# recebendo banco de dados de despesas de 2018
despesas_cand2018 = pd.read_csv(r'C:\Users\Vitor\Creative Cloud Files\Insper\2º Trimestre\Análise Exploratória de Dados II\Projeto Final\2018\Despesas\despesas_contratadas_candidatos_2018_BRASIL.csv',
                          sep = ';',
                          encoding = 'latin1',
                          decimal = ',',
                          low_memory = False)

# %%
# recebendo conjunto de dados dos candidatos em 2018
cand2018 = pd.read_csv(r'C:\Users\Vitor\Creative Cloud Files\Insper\2º Trimestre\Análise Exploratória de Dados II\Projeto Final\2018\consulta_cand_2018_BRASIL.csv',
                          sep = ';',
                          encoding = 'latin1',
                          decimal = ',',
                          low_memory = False)

# %% [markdown]
# # Etapa 2: ```<merge()>``` e Primeiros tratamentos

# %% [markdown]
# ## Fazendo ```<merge()>``` dos dados para que cada tabela tenha descrição completa de cada ano

# %%
# criando dataframe único com dados de 2022
candidatos2022 = pd.merge(cand2022, despesas_cand2022,  how = 'inner', on = 'SQ_CANDIDATO')
candidatos2022.head(2)
# Out:
#   DT_GERACAO_x HH_GERACAO_x  ANO_ELEICAO_x  CD_TIPO_ELEICAO_x  \
# 0   05/12/2022     18:38:01           2022                  2
# 1   05/12/2022     18:38:01           2022                  2
#
#    NM_TIPO_ELEICAO_x  NR_TURNO  CD_ELEICAO_x                    DS_ELEICAO_x  \
# 0  ELEIÇÃO ORDINÁRIA         1           546  Eleições Gerais Estaduais 2022
# 1  ELEIÇÃO ORDINÁRIA         1           546  Eleições Gerais Estaduais 2022
#
#   DT_ELEICAO_x TP_ABRANGENCIA  ... DS_CARGO_CANDIDATO_DOADOR  \
# 0   02/10/2022       ESTADUAL  ...                    #NULO#
# 1   02/10/2022       ESTADUAL  ...                   Senador
#
#   NR_PARTIDO_DOADOR SG_PARTIDO_DOADOR                    NM_PARTIDO_DOADOR  \
# 0                90              PROS  Partido Republicano da Ordem Social
# 1                19              PODE                              Podemos
#
#         NR_RECIBO_DOACAO  NR_DOCUMENTO_DOACAO  SQ_RECEITA  DT_RECEITA  \
# 0  000900300000SC000001E                   01    29326029  02/09/2022
# 1  001900500000SE000001E               988001    31098572  16/08/2022
#
#   DS_RECEITA VR_RECEITA
# 0     #NULO#   600000.0
# 1     #NULO#       50.0
#
# [2 rows x 127 columns]

# %%
# criando dataframe único com dados de 2018
candidatos2018 = pd.merge(cand2018, despesas_cand2018, how = 'inner', on = 'SQ_CANDIDATO')
candidatos2018.head(2)
# Out:
#   DT_GERACAO_x HH_GERACAO_x  ANO_ELEICAO_x  CD_TIPO_ELEICAO_x  \
# 0   04/12/2022     10:01:35           2018                  2
# 1   04/12/2022     10:01:35           2018                  2
#
#    NM_TIPO_ELEICAO_x  NR_TURNO  CD_ELEICAO_x                    DS_ELEICAO_x  \
# 0  ELEIÇÃO ORDINÁRIA         1           297  Eleições Gerais Estaduais 2018
# 1  ELEIÇÃO ORDINÁRIA         1           297  Eleições Gerais Estaduais 2018
#
#   DT_ELEICAO_x TP_ABRANGENCIA  ... SG_PARTIDO_FORNECEDOR  \
# 0   07/10/2018       ESTADUAL  ...                #NULO#
# 1   07/10/2018       ESTADUAL  ...                #NULO#
#
#   NM_PARTIDO_FORNECEDOR DS_TIPO_DOCUMENTO  NR_DOCUMENTO CD_ORIGEM_DESPESA  \
# 0                #NULO#            #NULO#        #NULO#          20210000
# 1                #NULO#             Outro        000001          20600000
#
#                                    DS_ORIGEM_DESPESA  SQ_DESPESA  DT_DESPESA  \
# 0  Encargos financeiros, taxas bancárias e/ou op....    25251367  20/09/2018
# 1                      Cessão ou locação de veículos    25251388  31/08/2018
#
#                                   DS_DESPESA VR_DESPESA_CONTRATADA
# 0                          TARIFAS BANCARIAS                   9.7
# 1  ALUGUEL DE VEICULO· INCLUSO O MOSTORISTA.                3450.0
#
# [2 rows x 115 columns]

# %% [markdown]
# ## Modificando o formato da data

# %%
# Modificando a variável de data 
candidatos2022['DT_GERACAO_x'] = pd.to_datetime(candidatos2022['DT_GERACAO_x'], format = '%d/%m/%Y')
candidatos2018['DT_GERACAO_x'] = pd.to_datetime(candidatos2018['DT_GERACAO_x'], format = '%d/%m/%Y')

# %% [markdown]
# ## Fazendo filtro somente para deputados federais

# %%
# 2022
candidatos2022 = candidatos2022.query('  DS_CARGO_x == "DEPUTADO FEDERAL"   ')

# 2018
candidatos2018 = candidatos2018.query('  DS_CARGO_x == "DEPUTADO FEDERAL"   ')

# %% [markdown]
# ## Realizando agrupamento para fazer análise etnográfica dos candidatos

# %% [markdown]
# Criando novo Dataframe com Deputados Federais, total de verba distribuida para cada um e retirando as duplicatas

# %%
# criando novo dataframe com os dados que são necessários para a análise
cand2022_analise = candidatos2022[['NM_CANDIDATO_x', 'VR_RECEITA', 'DS_GENERO', 'DS_COR_RACA', 'SG_UF_x', 'NR_CPF_CANDIDATO_x', 'SG_PARTIDO_x']]
cand2018_analise = candidatos2018[['NM_CANDIDATO_x', 'VR_DESPESA_CONTRATADA', 'DS_GENERO', 'DS_COR_RACA', 'SG_UF_x', 'NR_CPF_CANDIDATO_x', 'SG_PARTIDO_x']]

# %%
# agrupando e retirando duplicadas para que cada linha fique com orçamento total de cada candidato
## 2022
cand2022_analise['total_cand'] = cand2022_analise.groupby(['NR_CPF_CANDIDATO_x'])['VR_RECEITA'].transform('sum')
cand2022_analise.drop_duplicates(subset = 'NM_CANDIDATO_x', inplace=True)
cand2022_analise.drop(columns=['VR_RECEITA'], inplace=True)

## 2018
cand2018_analise['total_cand'] = cand2018_analise.groupby(['NR_CPF_CANDIDATO_x'])['VR_DESPESA_CONTRATADA'].transform('sum')
cand2018_analise.drop_duplicates(subset = 'NM_CANDIDATO_x', inplace=True)
cand2018_analise.drop(columns=['VR_DESPESA_CONTRATADA'], inplace=True)

# %%
# renomeando as colunas e juntando os dois dataframes
## 2022
cand2022_analise.rename(columns= {'NM_CANDIDATO_x': 'Nome_Candidato',
                                  'DS_GENERO': 'Gênero',
                                  'DS_COR_RACA': 'Raça',
                                  'SG_UF_x': 'UF',
                                  'NR_CPF_CANDIDATO_x': 'CPF',
                                  'SG_PARTIDO_x': 'Partido'},
                                  inplace=True)
cand2022_analise.reset_index(inplace=True, drop = True)
cand2022_analise['ano'] = '2022'

## 2018
cand2018_analise.rename(columns= {'NM_CANDIDATO_x': 'Nome_Candidato',
                                  'DS_GENERO': 'Gênero',
                                  'DS_COR_RACA': 'Raça',
                                  'SG_UF_x': 'UF',
                                  'NR_CPF_CANDIDATO_x': 'CPF',
                                  'SG_PARTIDO_x': 'Partido'},
                                  inplace=True)
cand2018_analise.reset_index(inplace=True, drop = True)
cand2018_analise['ano'] = '2018'

# juntandos os dataframes
cand_analise = pd.concat([cand2022_analise, cand2018_analise])
cand_analise.head()

# %% [markdown]
# ## Retirando _missing data_ e substituindo por 0

# %%
# Localizando Missing Data
missing_nome = cand_analise[cand_analise['Nome_Candidato'].isna()]
missing_cpf = missing_nome[['CPF']]

# Retirando Missing e substituindo o valor por 0
cand_analise.loc[cand_analise['CPF'].isin(missing_cpf)]
cand_analise['total_cand'] = cand_analise['total_cand'].fillna(0)
cand_analise.head(2)
# Out:
#                            Nome_Candidato     Gênero    Raça  UF          CPF  \
# 0  CARLOS EDUARDO ALVES TEIXEIRA DO PRADO  MASCULINO  BRANCA  PR   7051262939
# 1                   ELIZEU ANTONIO MACIEL  MASCULINO  BRANCA  PE  13626434400
#
#   Partido  total_cand   ano
# 0     PSC     30000.0  2022
# 1  AVANTE     70000.0  2022

# %% [markdown]
# # Etapa 3: Começando as análises exploratórias

# %% [markdown]
# ## Fazendo Estatística Descritiva Univariada

# %%
# Estatística Descritiva do total do orçamento de todos os candidatos - 2022
pd.set_option('display.float_format', lambda x: '%.2f' %x)
cand_analise.query('  ano == "2022"  ').describe()['total_cand']
# Out:
# count      9287.00
# mean     348340.22
# std      638809.86
# min          13.40
# 25%       20686.83
# 50%       77608.71
# 75%      313903.81
# max     3789999.99
# Name: total_cand, dtype: float64

# %%
# Estatística Descritiva do total do orçamento de todos os candidatos - 2018
cand_analise.query('  ano == "2018"   ').describe()['total_cand']
# Out:
# count      6171.00
# mean     208280.51
# std      459720.22
# min           2.85
# 25%        4029.25
# 50%       19859.00
# 75%      105108.29
# max     2591858.00
# Name: total_cand, dtype: float64

# %%
# verificando as legendas dos partidos, que podem aparecer de maneira diferente do normal
cand_analise['Partido'].unique()
# Out:
# array(['PSC', 'AVANTE', 'PT', 'AGIR', 'PSD', 'PRTB', 'REPUBLICANOS',
#        'PDT', 'PMB', 'PSDB', 'DC', 'NOVO', 'PSOL', 'PATRIOTA', 'PROS',
#        'MDB', 'PODE', 'PL', 'REDE', 'CIDADANIA', 'PP', 'SOLIDARIEDADE',
#        'PSB', 'UNIÃO', 'PCO', 'PMN', 'PV', 'PTB', 'PSTU', 'PC do B', 'UP',
#        'PCB', 'PR', 'PRB', 'PHS', 'DEM', 'PPS', 'PSL', 'PRP', 'PTC',
#        'PPL'], dtype=object)

# %% [markdown]
# ## Descrição da distribuição de recursos por gênero

# %% [markdown]
# ### 2022

# %%
# Mulheres
cand_analise.query('  ano == "2022" and Gênero == "FEMININO"  ').describe()['total_cand']
# Out:
# count      3290.00
# mean     294040.74
# std      557686.19
# min          16.50
# 25%       24948.91
# 50%       79237.68
# 75%      267646.46
# max     3313917.40
# Name: total_cand, dtype: float64

# %%
cand_analise.query('  total_cand == 16.50 ')
# Out:
#               Nome_Candidato    Gênero    Raça  UF          CPF Partido  \
# 6046  TELMA GIMENEZ LOUREIRO  FEMININO  BRANCA  SP  10410739847     PDT
#
#       total_cand   ano
# 6046       16.50  2022

# %%
# Homens
cand_analise.query('  ano == "2022" and Gênero == "MASCULINO"  ').describe()['total_cand']
# Out:
# count      5997.00
# mean     378129.33
# std      677409.46
# min          13.40
# 25%       20000.00
# 50%       76585.27
# 75%      350000.00
# max     3789999.99
# Name: total_cand, dtype: float64

# %%
cand_analise.query('  total_cand == 13.40 ')
# Out:
#           Nome_Candidato     Gênero    Raça  UF         CPF Partido  \
# 275  FÁBIO ALVES GARRIDO  MASCULINO  BRANCA  RJ  3389817727    PRTB
#
#      total_cand   ano
# 275       13.40  2022

# %% [markdown]
# ### 2018

# %%
# Mulheres
cand_analise.query('  ano == "2018" and Gênero == "FEMININO"  ').describe()['total_cand']
# Out:
# count      1877.00
# mean     145191.25
# std      387570.65
# min           9.90
# 25%        4000.00
# 50%       15000.00
# 75%       75945.51
# max     2500000.00
# Name: total_cand, dtype: float64

# %%
# Homens
cand_analise.query('  ano == "2018" and Gênero == "MASCULINO"  ').describe()['total_cand']
# Out:
# count      4293.00
# mean     235913.01
# std      485434.74
# min           2.85
# 25%        4100.00
# 50%       20139.22
# 75%      137876.32
# max     2591858.00
# Name: total_cand, dtype: float64

# %% [markdown]
# ## Descrição da distribuição recursos por Raça

# %% [markdown]
# ### 2022

# %%
cand_analise['Raça'].unique()
# Out:
# array(['BRANCA', 'PARDA', 'PRETA', 'INDÍGENA', 'NÃO INFORMADO', 'AMARELA',
#        'NÃO DIVULGÁVEL'], dtype=object)

# %%
cand_analise.query('  total_cand == 3789999.99  ')
# Out:
#                     Nome_Candidato     Gênero    Raça  UF         CPF  \
# 8083  ARNALDO CALIL PEREIRA JARDIM  MASCULINO  BRANCA  SP  4197807856
#
#         Partido  total_cand   ano
# 8083  CIDADANIA  3789999.99  2022

# %%
# Brancos
cand_analise.query('  ano == "2022" and Raça == "BRANCA"  ').describe()['total_cand']
# Out:
# count      4759.00
# mean     429471.97
# std      721556.80
# min          13.40
# 25%       25013.13
# 50%      100000.00
# 75%      429264.30
# max     3789999.99
# Name: total_cand, dtype: float64

# %%
# Não brancos
cand_analise.query('  ano == "2022" and Raça != "BRANCA"  ').describe()['total_cand']
# Out:
# count      4528.00
# mean     263069.46
# std      525038.73
# min          40.00
# 25%       20000.00
# 50%       60000.00
# 75%      228695.00
# max     3332410.09
# Name: total_cand, dtype: float64

# %%
cand_analise.query(' total_cand == 3332410.09  ')
# Out:
#                    Nome_Candidato     Gênero   Raça  UF          CPF Partido  \
# 3580  JOSÉ MENDONÇA BEZERRA FILHO  MASCULINO  PARDA  PE  40530086468   UNIÃO
#
#       total_cand   ano
# 3580  3332410.09  2022

# %% [markdown]
# ### 2018

# %%
# Brancos
cand_analise.query('  ano == "2018" and Raça == "BRANCA"  ').describe()['total_cand']
# Out:
# count      3745.00
# mean     266263.42
# std      525525.30
# min          10.00
# 25%        5444.00
# 50%       27500.00
# 75%      187029.00
# max     2591858.00
# Name: total_cand, dtype: float64

# %%
# Não brancos
cand_analise.query('  ano == "2018" and Raça != "BRANCA"  ').describe()['total_cand']
# Out:
# count      2426.00
# mean     118772.67
# std      313247.86
# min           2.85
# 25%        3000.00
# 50%       11342.50
# 75%       54213.88
# max     2448076.40
# Name: total_cand, dtype: float64

# %% [markdown]
# ## Descrição da distribuição de mulheres e homens por raça

# %% [markdown]
# ### Brancos em 2022

# %%
# Homens
cand_analise.query('  ano == "2022" and Raça == "BRANCA" and Gênero == "MASCULINO"  ').describe()['total_cand']
# Out:
# count      3201.00
# mean     473708.98
# std      763543.85
# min          13.40
# 25%       25000.00
# 50%      106000.00
# 75%      503358.90
# max     3789999.99
# Name: total_cand, dtype: float64

# %%
cand_analise.query('  total_cand == 3789999.99  ').head()
# Out:
#                     Nome_Candidato     Gênero    Raça  UF         CPF  \
# 8083  ARNALDO CALIL PEREIRA JARDIM  MASCULINO  BRANCA  SP  4197807856
#
#         Partido  total_cand   ano
# 8083  CIDADANIA  3789999.99  2022

# %%
# Mulheres
cand_analise.query('  ano == "2022" and Raça == "BRANCA" and Gênero == "FEMININO"  ').describe()['total_cand']
# Out:
# count      1558.00
# mean     338584.50
# std      616875.55
# min          16.50
# 25%       27972.18
# 50%       92050.00
# 75%      313287.03
# max     3313917.40
# Name: total_cand, dtype: float64

# %%
cand_analise.query('  total_cand == 3313917.40  ').head()
# Out:
#                         Nome_Candidato    Gênero    Raça  UF          CPF  \
# 5028  RENATA HELLMEISTER DE ABREU MELO  FEMININO  BRANCA  SP  30669688800
#
#      Partido  total_cand   ano
# 5028    PODE  3313917.40  2022

# %% [markdown]
# ### Não brancos em 2022

# %%
# Homens
cand_analise.query('  ano == "2022" and Raça != "BRANCA" and Gênero == "MASCULINO"  ').describe()['total_cand']
# Out:
# count      2796.00
# mean     268704.98
# std      542685.09
# min          40.00
# 25%       16611.25
# 50%       55117.04
# 75%      229425.44
# max     3332410.09
# Name: total_cand, dtype: float64

# %%
cand_analise.query('  total_cand == 3332410.09  ').head()['total_cand']
# Out:
# 3580   3332410.09
# Name: total_cand, dtype: float64

# %%
# Mulheres
cand_analise.query('  ano == "2022" and Raça != "BRANCA" and Gênero == "FEMININO"  ').describe()['total_cand']
# Out:
# count      1732.00
# mean     253971.93
# std      495245.41
# min         100.00
# 25%       21115.00
# 50%       69693.52
# 75%      226673.75
# max     3245823.67
# Name: total_cand, dtype: float64

# %%
cand_analise.query('  total_cand == 3245823.67  ').head()
# Out:
#                      Nome_Candidato    Gênero   Raça  UF         CPF Partido  \
# 284  SILVIA CRISTINA AMANCIO CHAGAS  FEMININO  PRETA  RO  1739396782      PL
#
#      total_cand   ano
# 284  3245823.67  2022

# %% [markdown]
# ### Brancos em 2018

# %%
# Homens
cand_analise.query('  ano == "2018" and Raça == "BRANCA" and Gênero == "MASCULINO"  ').describe()['total_cand']
# Out:
# count      2670.00
# mean     298243.55
# std      549038.67
# min          10.00
# 25%        5977.50
# 50%       30000.00
# 75%      238358.23
# max     2591858.00
# Name: total_cand, dtype: float64

# %%
# Mulheres
cand_analise.query('  ano == "2018" and Raça == "BRANCA" and Gênero == "FEMININO"  ').describe()['total_cand']
# Out:
# count      1075.00
# mean     186833.69
# std      452533.25
# min          10.00
# 25%        5000.00
# 50%       20856.40
# 75%       99815.76
# max     2500000.00
# Name: total_cand, dtype: float64

# %% [markdown]
# ### Não brancos em 2018

# %%
# Homens
cand_analise.query('  ano == "2018" and Raça != "BRANCA" and Gênero == "MASCULINO"  ').describe()['total_cand']
# Out:
# count      1623.00
# mean     133372.93
# std      332577.32
# min           2.85
# 25%        2979.95
# 50%       13250.00
# 75%       60008.19
# max     2448076.40
# Name: total_cand, dtype: float64

# %%
# Mulheres
cand_analise.query('  ano == "2018" and Raça != "BRANCA" and Gênero == "FEMININO"  ').describe()['total_cand']
# Out:
# count       802.00
# mean      89373.75
# std      267910.18
# min           9.90
# 25%        3000.00
# 50%       10000.00
# 75%       50000.00
# max     2425175.92
# Name: total_cand, dtype: float64

# %% [markdown]
# ## Descrição da distribuição por estado e por gênero

# %%
# pedindo ao pandas para mostrar a tabela completa
pd.set_option('display.max_columns', None) # coluna
pd.set_option('display.max_rows', None) # linha

# Sincretizando os dados de Raças e agrupando os valores para receber uma estatística descritiva do cruzamento
sinc_raca = cand_analise.replace(to_replace = ['PARDA', 'PRETA', 'INDÍGENA', 'NÃO INFORMADO', 'AMARELA'], value = 'NÃO BRANCO')
comp_estado_2022 = sinc_raca.query('    ano == "2022"  ')
comp_estado_2022 = comp_estado_2022.groupby(['UF', 'Gênero', 'Raça']).describe()
comp_estado_2022.sort_values(by=('total_cand', '50%'), ascending=False).head(10)
# Out:
#                         total_cand                                        \
#                              count      mean       std     min       25%
# UF Gênero    Raça
# MT FEMININO  BRANCA          25.00 761055.59 825918.02 2000.00 119808.52
# PI MASCULINO BRANCA          26.00 891067.03 931559.74  300.00  68063.39
# RO MASCULINO BRANCA          34.00 817487.59 875817.11 5000.00 126278.00
# AP MASCULINO BRANCA          27.00 640652.62 703063.12 1434.55 207171.20
# AC MASCULINO BRANCA          16.00 766741.00 852024.14 9582.96 187854.93
# AL MASCULINO BRANCA          42.00 713639.75 916574.12 2000.00  63601.36
# AP FEMININO  BRANCA          15.00 407733.19 323672.48 3000.00 192031.55
# TO FEMININO  NÃO BRANCO      34.00 466155.68 502811.91 4758.32 115625.00
# RR MASCULINO BRANCA          24.00 430416.95 484489.98 4133.33  40155.00
# TO MASCULINO NÃO BRANCO      66.00 493055.03 656710.00  800.00  51858.65
#
#
#                               50%        75%        max
# UF Gênero    Raça
# MT FEMININO  BRANCA     508000.00 1134250.00 2550968.11
# PI MASCULINO BRANCA     480719.70 1814000.97 2927621.10
# RO MASCULINO BRANCA     462757.00 1230978.79 2886050.00
# AP MASCULINO BRANCA     456800.00  667300.00 3170000.00
# AC MASCULINO BRANCA     417409.83 1067449.71 3025100.00
# AL MASCULINO BRANCA     380310.00  756873.51 3238300.00
# AP FEMININO  BRANCA     335926.00  601550.00 1021931.00
# TO FEMININO  NÃO BRANCO 316620.00  550000.00 1965101.12
# RR MASCULINO BRANCA     300910.43  562847.50 1916407.41
# TO MASCULINO NÃO BRANCO 300400.00  591685.00 2870000.00

# %%
# orçamento por estado caso a distribuição fosse igual - 2022
cand2022_analise['total'] = cand2022_analise['total_cand'].sum()
cand2022_analise['igualitário'] = cand2022_analise['total'] / cand2022_analise['CPF'].count()
cand2022_analise['igualitário'].head(1)

# %%
# orçamento por estado caso a distribuição fosse igual - 2018
cand2018_analise['total'] = cand2018_analise['total_cand'].sum()
cand2018_analise['igualitário'] = cand2018_analise['total'] / cand2018_analise['CPF'].count()
cand2018_analise['igualitário'].head(1)

# %%
# descrevendo os dados, realizando agrupamento por Unidade Federativa, Gênero e Raça
distribuicao_estado = sinc_raca.groupby(['UF', 'Gênero', 'Raça']).agg({'total_cand': ['sum', 'mean', 'median', 'max'], 'Nome_Candidato': 'count'})
distribuicao_estado
# Out:
#                                    total_cand                                 \
#                                           sum      mean    median        max
# UF Gênero         Raça
# AC FEMININO       BRANCA           9786117.61 391444.70 123362.96 1669311.96
#                   NÃO BRANCO      23825545.67 541489.67  80973.65 2913700.00
#    MASCULINO      BRANCA          18716515.45 719865.98 417409.83 3025100.00
#                   NÃO BRANCO      26776619.22 297517.99  96028.68 2577602.00
# AL FEMININO       BRANCA          13800302.53 372981.15 271393.20 2293340.05
#                   NÃO BRANCO       7644019.27 254800.64  57189.00 1908530.34
#    MASCULINO      BRANCA          39547513.73 573152.37 286180.29 3238300.00
#                   NÃO BRANCO      27369819.67 441448.70  52555.00 3171500.00
# AM FEMININO       BRANCA          12050015.52 634211.34 115662.40 3174965.00
#                   NÃO BRANCO      15483268.79 258054.48  49705.00 2568230.00
#    MASCULINO      BRANCA          31770170.15 557371.41 193399.75 2773073.46
#                   NÃO BRANCO      29225782.52 324730.92  55540.71 3146220.54
# AP FEMININO       BRANCA           9008053.87 409456.99 306632.40 1952424.60
#                   NÃO BRANCO      20867919.91 372641.43 181381.27 2266964.00
#    MASCULINO      BRANCA          23638146.16 549724.33 400000.00 3170000.00
#                   NÃO BRANCO      28700904.31 322482.07 134900.00 2550000.00
# BA FEMININO       BRANCA          17028271.82 274649.55  74379.27 3003364.70
#                   NÃO BRANCO      54392029.18 203715.47  35147.53 3126189.27
#    MASCULINO      BRANCA          94952030.93 518863.56  60000.00 3093339.70
#                   NÃO BRANCO     110235668.62 233550.15  30110.76 3147847.70
# CE FEMININO       BRANCA          23393349.75 349154.47  60766.32 2531050.69
#                   NÃO BRANCO      20437078.89 185791.63  47330.54 2906162.90
#    MASCULINO      BRANCA          61018434.99 404095.60  99878.59 2925148.19
#                   NÃO BRANCO      50724114.71 257482.82  32829.77 3070740.20
# DF FEMININO       BRANCA          27057181.41 443560.35  91989.35 3119669.59
#                   NÃO BRANCO      11649446.41 200852.52  78188.98 2258998.69
#    MASCULINO      BRANCA          45728535.09 397639.44  58235.00 3048153.82
#                   NÃO BRANCO      21105569.96 188442.59  30043.00 1589050.00
# ES FEMININO       BRANCA          24105594.13 415613.69 134564.60 2712000.00
#                   NÃO BRANCO      11772020.93 210214.66  68670.75 2037078.23
#    MASCULINO      BRANCA          52649802.28 474322.54 159400.00 2693959.99
#                   NÃO BRANCO      32039379.71 368268.73 104319.10 2769749.20
# GO FEMININO       BRANCA          35364311.70 346708.94  69084.29 3161250.00
#                   NÃO BRANCO      15470730.49 200918.58  45000.00 3146888.94
#    MASCULINO      BRANCA          93233625.85 545225.88 150000.00 3268149.50
#                   NÃO BRANCO      33037180.66 220247.87  45667.29 2989960.41
# MA FEMININO       BRANCA          11001823.03 224527.00  84100.44 3148240.00
#                   NÃO BRANCO      20553336.71 197628.24  50471.20 2708862.00
#    MASCULINO      BRANCA          54407143.45 503769.85 148752.26 3322098.85
#                   NÃO BRANCO      64877870.74 322775.48  67036.35 3178220.05
# MG FEMININO       BRANCA          52569819.82 215450.08  50000.00 2938215.32
#                   NÃO BRANCO      36174015.24 143547.68  35129.26 3040391.77
#    MASCULINO      BRANCA         281497766.29 459213.32  88340.64 3187491.55
#                   NÃO BRANCO      81242509.14 175091.61  20310.28 3211000.00
#    NÃO DIVULGÁVEL NÃO DIVULGÁVEL       500.00    500.00    500.00     500.00
# MS FEMININO       BRANCA          13259928.94 250187.34  95631.32 2221509.60
#                   NÃO BRANCO       8442384.03 248305.41 119250.00 3100000.00
#    MASCULINO      BRANCA          41990286.20 428472.31  80000.00 2823658.31
#                   NÃO BRANCO      10483255.25 177682.29  53000.00 1036000.00
# MT FEMININO       BRANCA          22720475.38 568011.88 143825.00 2550968.11
#                   NÃO BRANCO      11677877.34 248465.48  75000.00 3204000.52
#    MASCULINO      BRANCA          56673193.73 651416.02 223615.88 3290237.67
#                   NÃO BRANCO      24218572.09 306564.20  80000.00 2619349.52
# PA FEMININO       BRANCA          17344742.15 433618.55 157203.59 2591487.00
#                   NÃO BRANCO      25655823.12 270061.30  73571.95 2425175.92
#    MASCULINO      BRANCA          40506561.75 493982.46 164427.88 3030500.60
#                   NÃO BRANCO      40487218.63 238160.11  64197.51 2955584.00
# PB FEMININO       BRANCA          13343572.83 256607.17  75069.89 1458991.64
#                   NÃO BRANCO      13709828.31 263650.54 130500.00 1899340.00
#    MASCULINO      BRANCA          44439836.07 373444.00  42118.64 2920798.05
#                   NÃO BRANCO      26858311.87 291938.17  44278.62 3186350.00
# PE FEMININO       BRANCA          32589762.72 370338.21  70497.15 3222544.00
#                   NÃO BRANCO      13425866.46 113778.53  25235.00 1566000.00
#    MASCULINO      BRANCA         120936748.19 532761.01  54918.85 3178304.00
#                   NÃO BRANCO      38179502.97 177579.08  31686.92 3332410.09
# PI FEMININO       BRANCA          21713632.84 504968.21 100000.00 3073160.00
#                   NÃO BRANCO       8956415.16 151803.65  24140.00 3050966.00
#    MASCULINO      BRANCA          33974872.56 566247.88  91598.60 2927621.10
#                   NÃO BRANCO      26239265.75 257247.70  23339.33 2688615.09
# PR FEMININO       BRANCA          45045626.83 184613.22  42403.00 3156387.35
#                   NÃO BRANCO      10535520.51 152688.70  60997.37 1329950.55
#    MASCULINO      BRANCA         168232713.00 341936.41  38077.09 3165241.66
#                   NÃO BRANCO      22189732.12 150950.56  33183.00 3176642.30
# RJ FEMININO       BRANCA          56178773.58 205783.05  25000.00 3081522.00
#                   NÃO BRANCO      39918668.41 133955.26  20817.92 3176000.00
#    MASCULINO      BRANCA         198554497.54 288596.65  43375.71 3062000.00
#                   NÃO BRANCO      62625471.66 128594.40  17962.45 3205227.85
# RN FEMININO       BRANCA          22885322.63 423802.27 115416.04 2516500.00
#                   NÃO BRANCO       9081863.84 221508.87  44919.80 2722500.00
#    MASCULINO      BRANCA          45392412.77 504360.14 180500.00 3083404.69
#                   NÃO BRANCO       9700008.56 138571.55  22197.88 1830976.97
# RO FEMININO       BRANCA          14522165.76 440065.63 159300.00 2467996.50
#                   NÃO BRANCO      19685675.18 410118.23 209643.33 3245823.67
#    MASCULINO      BRANCA          33673688.30 534502.99 129212.00 2886050.00
#                   NÃO BRANCO      26636667.49 317103.18  84200.00 2101406.01
# RR FEMININO       BRANCA          11166416.76 446656.67 102324.02 2446865.25
#                   NÃO BRANCO      14950554.57 210571.19  52050.00 2117575.70
#    MASCULINO      BRANCA          13415434.44 285434.78  61064.10 1916407.41
#                   NÃO BRANCO      22223230.86 203882.85  52000.00 1799236.12
# RS FEMININO       BRANCA          35134337.98 156152.61  49500.00 2542295.26
#                   NÃO BRANCO       8925502.45 137315.42  59007.43 1592025.26
#    MASCULINO      BRANCA         154208947.34 316001.94  47280.02 3190936.07
#                   NÃO BRANCO       9249102.39  96344.82  35498.15 1746512.59
# SC FEMININO       BRANCA          38522043.69 298620.49  71004.68 3201072.53
#                   NÃO BRANCO       6450761.23 189728.27  94326.47 1625000.00
#    MASCULINO      BRANCA          84207612.92 301819.40  76408.38 2863867.20
#                   NÃO BRANCO       5348423.08 152812.09  41837.49  678859.54
# SE FEMININO       BRANCA           9689383.57 302793.24  39503.00 3056673.93
#                   NÃO BRANCO      11303082.30 205510.59  25000.00 2317752.27
#    MASCULINO      BRANCA          22600333.71 426421.39  52352.52 2223510.00
#                   NÃO BRANCO      17426969.66 169193.88  19208.46 2528845.00
# SP FEMININO       BRANCA         122289794.52 233377.47  35127.40 3313917.40
#                   NÃO BRANCO      54584910.04 186296.62  30000.00 2923182.52
#    MASCULINO      BRANCA         436871869.73 335539.07  48651.05 3789999.99
#                   NÃO BRANCO      83197779.18 178536.01  25000.00 3093528.55
# TO FEMININO       BRANCA          16790045.54 524688.92 193061.23 2525000.00
#                   NÃO BRANCO      15982993.37 389829.11 228560.00 1965101.12
#    MASCULINO      BRANCA          19814040.30 404368.17 172947.20 3147404.99
#                   NÃO BRANCO      37364458.85 410598.45 203000.00 2870000.00
#
#                                  Nome_Candidato
#                                           count
# UF Gênero         Raça
# AC FEMININO       BRANCA                     25
#                   NÃO BRANCO                 44
#    MASCULINO      BRANCA                     26
#                   NÃO BRANCO                 90
# AL FEMININO       BRANCA                     37
#                   NÃO BRANCO                 30
#    MASCULINO      BRANCA                     69
#                   NÃO BRANCO                 62
# AM FEMININO       BRANCA                     19
#                   NÃO BRANCO                 60
#    MASCULINO      BRANCA                     57
#                   NÃO BRANCO                 90
# AP FEMININO       BRANCA                     22
#                   NÃO BRANCO                 56
#    MASCULINO      BRANCA                     43
#                   NÃO BRANCO                 89
# BA FEMININO       BRANCA                     62
#                   NÃO BRANCO                267
#    MASCULINO      BRANCA                    183
#                   NÃO BRANCO                472
# CE FEMININO       BRANCA                     67
#                   NÃO BRANCO                110
#    MASCULINO      BRANCA                    151
#                   NÃO BRANCO                197
# DF FEMININO       BRANCA                     61
#                   NÃO BRANCO                 58
#    MASCULINO      BRANCA                    115
#                   NÃO BRANCO                112
# ES FEMININO       BRANCA                     58
#                   NÃO BRANCO                 56
#    MASCULINO      BRANCA                    111
#                   NÃO BRANCO                 87
# GO FEMININO       BRANCA                    102
#                   NÃO BRANCO                 77
#    MASCULINO      BRANCA                    171
#                   NÃO BRANCO                150
# MA FEMININO       BRANCA                     49
#                   NÃO BRANCO                104
#    MASCULINO      BRANCA                    108
#                   NÃO BRANCO                201
# MG FEMININO       BRANCA                    244
#                   NÃO BRANCO                252
#    MASCULINO      BRANCA                    613
#                   NÃO BRANCO                464
#    NÃO DIVULGÁVEL NÃO DIVULGÁVEL              1
# MS FEMININO       BRANCA                     53
#                   NÃO BRANCO                 34
#    MASCULINO      BRANCA                     98
#                   NÃO BRANCO                 59
# MT FEMININO       BRANCA                     40
#                   NÃO BRANCO                 47
#    MASCULINO      BRANCA                     87
#                   NÃO BRANCO                 79
# PA FEMININO       BRANCA                     40
#                   NÃO BRANCO                 95
#    MASCULINO      BRANCA                     82
#                   NÃO BRANCO                170
# PB FEMININO       BRANCA                     52
#                   NÃO BRANCO                 52
#    MASCULINO      BRANCA                    119
#                   NÃO BRANCO                 92
# PE FEMININO       BRANCA                     88
#                   NÃO BRANCO                118
#    MASCULINO      BRANCA                    227
#                   NÃO BRANCO                215
# PI FEMININO       BRANCA                     43
#                   NÃO BRANCO                 59
#    MASCULINO      BRANCA                     60
#                   NÃO BRANCO                102
# PR FEMININO       BRANCA                    244
#                   NÃO BRANCO                 69
#    MASCULINO      BRANCA                    492
#                   NÃO BRANCO                147
# RJ FEMININO       BRANCA                    273
#                   NÃO BRANCO                298
#    MASCULINO      BRANCA                    688
#                   NÃO BRANCO                487
# RN FEMININO       BRANCA                     54
#                   NÃO BRANCO                 41
#    MASCULINO      BRANCA                     90
#                   NÃO BRANCO                 70
# RO FEMININO       BRANCA                     33
#                   NÃO BRANCO                 48
#    MASCULINO      BRANCA                     63
#                   NÃO BRANCO                 84
# RR FEMININO       BRANCA                     25
#                   NÃO BRANCO                 71
#    MASCULINO      BRANCA                     47
#                   NÃO BRANCO                109
# RS FEMININO       BRANCA                    225
#                   NÃO BRANCO                 65
#    MASCULINO      BRANCA                    488
#                   NÃO BRANCO                 96
# SC FEMININO       BRANCA                    129
#                   NÃO BRANCO                 34
#    MASCULINO      BRANCA                    279
#                   NÃO BRANCO                 35
# SE FEMININO       BRANCA                     32
#                   NÃO BRANCO                 55
#    MASCULINO      BRANCA                     53
#                   NÃO BRANCO                103
# SP FEMININO       BRANCA                    524
#                   NÃO BRANCO                293
#    MASCULINO      BRANCA                   1302
#                   NÃO BRANCO                466
# TO FEMININO       BRANCA                     32
#                   NÃO BRANCO                 41
#    MASCULINO      BRANCA                     49
#                   NÃO BRANCO                 91

# %%
# exportando os últimos dois Dataframes anteriores para CSV
distribuicao_estado.to_csv(r'distribuicao_estado.csv')
comp_estado_2022.to_csv(r'comp_estado_2022.csv')

# %% [markdown]
# # Etapa 4: Criando visualização de dados

# %% [markdown]
# ## Gráfico comparando os dados do total de candidatos por gênero e raça

# %%
# criando porcentagem para aparecer na visualização
cand_analise['porcentagem_orçamento'] = (cand_analise['total_cand'] / cand_analise['total_cand'].sum()) * 100
cand_analise.sort_values(by=('porcentagem_orçamento'), ascending=False).head(10)
# Out:
#                         Nome_Candidato     Gênero    Raça  UF          CPF  \
# 8083      ARNALDO CALIL PEREIRA JARDIM  MASCULINO  BRANCA  SP   4197807856
# 3580       JOSÉ MENDONÇA BEZERRA FILHO  MASCULINO   PARDA  PE  40530086468
# 3888     FÁBIO HENRIQUE DIAS DE MACEDO  MASCULINO  BRANCA  MA  65002865372
# 5028  RENATA HELLMEISTER DE ABREU MELO   FEMININO  BRANCA  SP  30669688800
# 3409              CARLOS GOMES BEZERRA  MASCULINO  BRANCA  MT    834939134
# 3729      LUIZ PAULO TEIXEIRA FERREIRA  MASCULINO  BRANCA  SP   2441369806
# 527            GLAUSKSTON BATISTA RIOS  MASCULINO  BRANCA  GO  60751266191
# 284     SILVIA CRISTINA AMANCIO CHAGAS   FEMININO   PRETA  RO   1739396782
# 3542     ISNALDO BULHÕES BARROS JÚNIOR  MASCULINO  BRANCA  AL  67766692449
# 97    FABÍOLA KARLA DE OLIVEIRA MACIEL   FEMININO  BRANCA  PE   4533024408
#
#             Partido  total_cand   ano  porcentagem_orçamento
# 8083      CIDADANIA  3789999.99  2022                   0.08
# 3580          UNIÃO  3332410.09  2022                   0.07
# 3888           PODE  3322098.85  2022                   0.07
# 5028           PODE  3313917.40  2022                   0.07
# 3409            MDB  3290237.67  2022                   0.07
# 3729             PT  3281293.48  2022                   0.07
# 527             PSC  3268149.50  2022                   0.07
# 284              PL  3245823.67  2022                   0.07
# 3542            MDB  3238300.00  2022                   0.07
# 97    SOLIDARIEDADE  3222544.00  2022                   0.07

# %%
# desativando limite do Altair para valores no Dataframe - raça
alt.data_transformers.disable_max_rows()

# Fazendo um template para fazer diversas análises com o orçamento total de cada candidato
def grafico_personalizado_mark(x_config, y_config, coluna_color, coluna_tamanho, título):
    base = alt.Chart(cand_analise).mark_point(filled=True).encode(
        size = alt.Size(coluna_tamanho, scale = alt.Scale(range=[1, 400]), legend=None),
        color = alt.Color(coluna_color, scale = alt.Scale(scheme = 'set1')),
        column = 'ano',
        tooltip = ['Nome_Candidato', 'Gênero', 'Raça', 'Partido', 'total_cand', 'porcentagem_orçamento']
    ).configure_mark(opacity = 0.5)\
    .properties(width = 400, height=400, title = título)
    return base.encode(x = x_config, y = y_config)

# %%
# Distribuição de Verba para Propaganda Eleitoral
grafico_personalizado_mark(x_config = alt.X('UF', title = 'Unidade Federativa'), \
                      y_config = alt.Y('total_cand', title = 'Orçamento por candidato'), \
                      coluna_color = 'Raça', coluna_tamanho = 'total_cand', título = 'Distribuição de Verba para Propaganda Eleitoral')

# %%
# Distribuição de Verba para Propaganda Eleitoral - gênero
grafico_personalizado_mark(x_config = alt.X('UF', title = 'Unidade Federativa'), \
                           y_config = alt.Y('total_cand', title = 'Orçamento por candidato'), \
                           coluna_color = 'Gênero', coluna_tamanho = 'total_cand', título = 'Distribuição de Verba para Propaganda Eleitoral - Gênero')

# %%
# Distribuição de verba por legenda e gênero
grafico_personalizado_mark(x_config = alt.X('Partido', title = 'Partido'), \
                           y_config = alt.Y('total_cand', title = 'Orçamento por candidato'), \
                           coluna_color = 'Gênero', coluna_tamanho = 'total_cand', título = 'Distribuição de Verba para Propaganda Eleitoral - Gênero e Partido')

# %%
# Distribuição de verba por legenda e raça
grafico_personalizado_mark(x_config = alt.X('Partido', title = 'Partido'), \
                           y_config = alt.Y('total_cand', title = 'Orçamento por candidato'), \
                           coluna_color = 'Raça', coluna_tamanho = 'total_cand', título = 'Distribuição de Verba para Propaganda Eleitoral - Raça e Partido')

# %%
# Distribuição de Verba para Propaganda Eleitoral - Dados Sincretizados
alt.Chart(sinc_raca).mark_point(filled=True).encode(
    x = alt.X('UF', title = 'Unidade Federativa'),
    y = alt.Y('total_cand', title = 'Orçamento por candidato'),
    size = alt.Size('total_cand', scale = alt.Scale(range=[1, 400]), legend=None),
    color = alt.Color('Raça', scale = alt.Scale(scheme = 'set1')),
    column = 'ano',
    tooltip = ['Nome_Candidato', 'Gênero', 'Raça', 'Partido', 'total_cand']
).configure_mark(opacity = 0.5)\
    .properties(width = 400, height=400, title = 'Distribuição de Verba para Propaganda Eleitoral')

# %% [markdown]
# ## Gráfico da distribuição de verba por Raça e Gênero em 2022, mostrando a distribuição em baixo

# %%
# Mostrando dataframe somente de dados da eleição de 2022
cand2022_analise.head()
# Out:
#                            Nome_Candidato     Gênero    Raça  UF          CPF  \
# 0  CARLOS EDUARDO ALVES TEIXEIRA DO PRADO  MASCULINO  BRANCA  PR   7051262939
# 1                   ELIZEU ANTONIO MACIEL  MASCULINO  BRANCA  PE  13626434400
# 2                  JOSEILDO RIBEIRO RAMOS  MASCULINO   PARDA  BA  15963330572
# 3             VALDIZIA FREITAS DE SANTANA   FEMININO   PRETA  BA  18918468504
# 4              VINICIUS SAUDINO DE MORAES  MASCULINO  BRANCA  SP  42411256892
#
#   Partido  total_cand   ano         total  igualitário
# 0     PSC    30000.00  2022 1285299017.25    348340.22
# 1  AVANTE    70000.00  2022 1285299017.25    348340.22
# 2      PT  2326699.00  2022 1285299017.25    348340.22
# 3    AGIR    10000.00  2022 1285299017.25    348340.22
# 4     PSD   105156.73  2022 1285299017.25    348340.22

# %%
# Configurando seleção
selecao = alt.selection(type='interval')
base = alt.Chart(sinc_raca).add_selection(selecao)

# Configurando gráfico de dispersão
## Raça
pontos_raca = base.mark_point(filled=True).encode(
    x = alt.X('UF', title = 'Unidade Federativa'), 
    y = alt.X('total_cand', title = 'Verba somanda dos candidatos'),
    color = alt.condition(selecao, 'Raça', alt.value('grey')),
    size = alt.Size('total_cand', scale = alt.Scale(range=[1, 400]), legend=None),
    tooltip = ['Nome_Candidato', 'Gênero', 'Partido', 'total_cand']
)

pontos_genero = base.mark_point(filled=True).encode(
    x = alt.X('UF', title = 'Unidade Federativa'), 
    y = alt.X('total_cand', title = 'Verba somanda dos candidatos'),
    color = alt.condition(selecao, 'Gênero', alt.value('grey')),
    size = alt.Size('total_cand', scale = alt.Scale(range=[1, 400]), legend=None),
    tooltip = ['Nome_Candidato', 'Gênero', 'Partido', 'total_cand']
)

# Configurando o ticks
## Raça
tick_axis = alt.Axis(labels=False, domain=False, ticks=False)

x_tick_raca = base.mark_tick().encode(
    alt.X('total_cand', title='', axis=tick_axis),
    alt.Y('Raça', axis=tick_axis),
    color=alt.condition(selecao, 'Raça', alt.value('lightgrey'))
)

x_tick_genero = base.mark_tick().encode(
    alt.X('total_cand', title='', axis=tick_axis),
    alt.Y('Gênero', axis=tick_axis),
    color=alt.condition(selecao, 'Gênero', alt.value('lightgrey'))
)

# Mostrando Gráfico
#(pontos_raca & x_tick_raca) | (pontos_genero & x_tick_genero)
alt.vconcat(alt.hconcat(alt.vconcat(pontos_raca, x_tick_raca), alt.vconcat(pontos_genero, x_tick_genero)))

# %%
# Recorte por partido
# Configurando seleção
selecao_p = alt.selection(type='interval')
base_p = alt.Chart(sinc_raca).add_selection(selecao_p)

# Configurando gráfico de dispersão
## Raça

pontos_raca_p = base_p.mark_point(filled=True).encode(
    x = alt.X('Partido', title = 'Partido'), 
    y = alt.X('total_cand', title = 'Verba somanda dos candidatos'),
    color = alt.condition(selecao_p, 'Raça', alt.value('grey')),
    size = alt.Size('total_cand', scale = alt.Scale(range=[1, 400]), legend=None),
    tooltip = ['Nome_Candidato', 'Gênero', 'UF', 'total_cand']
)

pontos_genero_p = base_p.mark_point(filled=True).encode(
    x = alt.X('Partido', title = 'Partido'), 
    y = alt.X('total_cand', title = 'Verba somanda dos candidatos'),
    color = alt.condition(selecao_p, 'Gênero', alt.value('grey')),
    size = alt.Size('total_cand', scale = alt.Scale(range=[1, 400]), legend=None),
    tooltip = ['Nome_Candidato', 'Gênero', 'UF', 'total_cand']
)

# Configurando o ticks
## Raça
tick_axis_p = alt.Axis(labels=False, domain=False, ticks=False)


x_tick_raca_p = base_p.mark_tick().encode(
    alt.X('total_cand', title='', axis=tick_axis),
    alt.Y('Raça', axis=tick_axis),
    color=alt.condition(selecao_p, 'Raça', alt.value('lightgrey'))
)

x_tick_genero_p = base_p.mark_tick().encode(
    alt.X('total_cand', title='', axis=tick_axis),
    alt.Y('Gênero', axis=tick_axis),
    color=alt.condition(selecao_p, 'Gênero', alt.value('lightgrey'))
)

# Mostrando Gráfico
#(pontos_raca & x_tick_raca) | (pontos_genero & x_tick_genero)
alt.vconcat(alt.hconcat(alt.vconcat(pontos_raca_p, x_tick_raca_p), alt.vconcat(pontos_genero_p, x_tick_genero_p)))

# %%
# Fazendo query para retirar não divulgável
limpo = sinc_raca.query('  Gênero != "NÃO DIVULGÁVEL"     ')

# por fim, boxplot com outliers nas eleições de 2022 - Estado
alt.Chart(limpo).mark_boxplot().encode(
    x = 'UF',
    y = 'total_cand',
    color = alt.Color('Raça', scale = alt.Scale(scheme = 'set1')),
    tooltip = ['Nome_Candidato', 'Gênero', 'Raça', 'Partido', 'total_cand'],
    column = 'Gênero'    
).properties(width=600, title = 'Análise de outliers de orçamentos por estado')

# %%
# por fim, boxplot com outliers nas eleições de 2022 - Partido
alt.Chart(limpo).mark_boxplot().encode(
    x = 'Partido',
    y = 'total_cand',
    color = alt.Color('Raça', scale = alt.Scale(scheme = 'set1')),
    tooltip = ['Nome_Candidato', 'Gênero', 'Raça', 'Partido', 'total_cand'],
    column = 'Gênero'   
).properties(width=600, title = 'Análise de outliers de orçamentos por partido')
